# %% [markdown]
# # Bokeh Function

# %%
from bokeh.plotting import figure, output_notebook, show, output_file
import pandas as pd
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Type - 1

# %%
p = figure(plot_width = 400, plot_height = 400) 
p.circle([1, 2, 3, 4, 5], [4, 7, 1, 6, 3], 
size = 10, color = "navy", alpha = 0.5)  
show(p)
# Out:
#   <div class="bk-root" id="5dcc4e2f-8a06-446f-b449-9c0adeef264f" data-root-id="1002"></div>

# %% [markdown]
# # Type - 2

# %%
p = figure(plot_width = 400, plot_height = 400) 
p.line([1, 2, 3, 4, 5], [3, 1, 2, 6, 5],  
        line_width = 2, color = "green") 
show(p)
# Out:
#   <div class="bk-root" id="0b2a2158-14c5-41b7-a66b-bb53e3c3ed74" data-root-id="1092"></div>

# %% [markdown]
# # Type - 3

# %%
p = figure(plot_width=400, plot_height=400)
p.square([1, 2, 3, 4], [4, 3, 2, 1], 
         size=10, color="red")
show(p)
# Out:
#   <div class="bk-root" id="4d4af701-4ed3-4e59-9270-34d91d4632a7" data-root-id="1191"></div>
